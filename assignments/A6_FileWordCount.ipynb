# %%
# Readf lines, words, chars count from file

file_name = "Leeladhar.txt" 
line_count = 0
word_count = 0
char_count = 0

try:
    with open(file_name, 'r') as file:
        for line in file:
            line_count += 1
            char_count += len(line) 
            words = line.split() 
            word_count += len(words)
            
    print("Lines:", line_count)
    print("Words:", word_count)
    print("Characters:", char_count)
    
except FileNotFoundError:
    print(f"Error: {file_name} file not found.")
# Out:
# Lines: 2
# Words: 5
# Characters: 29
